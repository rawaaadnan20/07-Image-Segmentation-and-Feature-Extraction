# %%
pip install opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\huawei\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\users\huawei\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: numpy in c:\users\huawei\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\huawei\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\huawei\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = cv2.imread('my_image.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

# Harris Corner Detection
harris = cv2.cornerHarris(gray, 2, 3, 0.04)

# Make corners clearer
harris = cv2.dilate(harris, None)

# Mark corners in red
image[harris > 0.01 * harris.max()] = [0, 0, 255]

# Show result
plt.figure(figsize=(10,8))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Harris Corner Detection")
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('my_image.jpg', 0)

ret, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)


plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.hist(img.ravel(),256)
plt.title('Histogram')

plt.subplot(1,3,3)
plt.imshow(thresh, cmap='gray')
plt.title('Otsu Threshold')

plt.show()
